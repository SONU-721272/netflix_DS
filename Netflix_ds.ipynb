# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv(r"C:\Users\sonic\OneDrive\Desktop\netflix-python\netflix_sample_data.csv")

# %%
df
# Out:
#              Title     Type             Director  \
# 0     The Irishman    Movie      Martin Scorsese
# 1  Stranger Things  TV Show  The Duffer Brothers
# 2     Breaking Bad  TV Show       Vince Gilligan
# 3      Money Heist  TV Show            Álex Pina
# 4       Extraction    Movie         Sam Hargrave
# 5         Bird Box    Movie         Susanne Bier
# 6             Dark  TV Show        Baran bo Odar
# 7        The Crown  TV Show         Peter Morgan
# 8     Enola Holmes    Movie       Harry Bradbeer
# 9           Narcos  TV Show       Chris Brancato
#
#                                 Cast         Country Release Date   Duration  \
# 0          Robert De Niro, Al Pacino   United States   2019-11-27    209 min
# 1  Millie Bobby Brown, Finn Wolfhard   United States   2016-07-15  3 Seasons
# 2         Bryan Cranston, Aaron Paul   United States   2008-01-20  5 Seasons
# 3       Úrsula Corberó, Álvaro Morte           Spain   2017-05-02  4 Seasons
# ...

# %%
type = df['Type'].value_counts()         -- 1

# %%
movie = type.get('Movie',0)

# %%
tv = type.get('TV Show',0)

# %%
tv
# Out:
# 6

# %%
movie
# Out:
# 4

# %%
ratio = movie / tv

# %%
ratio
# Out:
# 0.6666666666666666

# %%
genre = df['Genre'].value_counts()                      -- 2

# %%
genre
# Out:
# Genre
# Crime       2
# Sci-Fi      2
# Thriller    2
# Drama       1
# Action      1
# History     1
# Mystery     1
# Name: count, dtype: int64

# %%
country = df['Country'].value_counts()

# %%
country                                -- 3
# Out:
# Country
# United States     6
# United Kingdom    2
# Spain             1
# Germany           1
# Name: count, dtype: int64

# %%
df['Release Date']= pd.to_datetime(df['Release Date'])

# %%
df
# Out:
#              Title     Type             Director  \
# 0     The Irishman    Movie      Martin Scorsese
# 1  Stranger Things  TV Show  The Duffer Brothers
# 2     Breaking Bad  TV Show       Vince Gilligan
# 3      Money Heist  TV Show            Álex Pina
# 4       Extraction    Movie         Sam Hargrave
# 5         Bird Box    Movie         Susanne Bier
# 6             Dark  TV Show        Baran bo Odar
# 7        The Crown  TV Show         Peter Morgan
# 8     Enola Holmes    Movie       Harry Bradbeer
# 9           Narcos  TV Show       Chris Brancato
#
#                                 Cast         Country Release Date   Duration  \
# 0          Robert De Niro, Al Pacino   United States   2019-11-27    209 min
# 1  Millie Bobby Brown, Finn Wolfhard   United States   2016-07-15  3 Seasons
# 2         Bryan Cranston, Aaron Paul   United States   2008-01-20  5 Seasons
# 3       Úrsula Corberó, Álvaro Morte           Spain   2017-05-02  4 Seasons
# ...

# %%
df['Release Date'] = df['Release Date'].dt.year

# %%
df
# Out:
#              Title     Type             Director  \
# 0     The Irishman    Movie      Martin Scorsese
# 1  Stranger Things  TV Show  The Duffer Brothers
# 2     Breaking Bad  TV Show       Vince Gilligan
# 3      Money Heist  TV Show            Álex Pina
# 4       Extraction    Movie         Sam Hargrave
# 5         Bird Box    Movie         Susanne Bier
# 6             Dark  TV Show        Baran bo Odar
# 7        The Crown  TV Show         Peter Morgan
# 8     Enola Holmes    Movie       Harry Bradbeer
# 9           Narcos  TV Show       Chris Brancato
#
#                                 Cast         Country  Release Date   Duration  \
# 0          Robert De Niro, Al Pacino   United States          2019    209 min
# 1  Millie Bobby Brown, Finn Wolfhard   United States          2016  3 Seasons
# 2         Bryan Cranston, Aaron Paul   United States          2008  5 Seasons
# 3       Úrsula Corberó, Álvaro Morte           Spain          2017  4 Seasons
# ...

# %%
release_date = df['Release Date'].value_counts()

# %%
release_date
# Out:
# Release Date
# 2016    2
# 2017    2
# 2020    2
# 2019    1
# 2008    1
# 2018    1
# 2015    1
# Name: count, dtype: int64

# %%
movie = df[df['Type']=='Movie']                            -- 4

# %%
movie
# Out:
#           Title   Type         Director                              Cast  \
# 0  The Irishman  Movie  Martin Scorsese         Robert De Niro, Al Pacino
# 4    Extraction  Movie     Sam Hargrave                   Chris Hemsworth
# 5      Bird Box  Movie     Susanne Bier                    Sandra Bullock
# 8  Enola Holmes  Movie   Harry Bradbeer  Millie Bobby Brown, Henry Cavill
#
#           Country  Release Date Duration     Genre Rating
# 0   United States          2019  209 min     Crime      R
# 4   United States          2020  117 min    Action      R
# 5   United States          2018  124 min  Thriller      R
# 8  United Kingdom          2020  123 min   Mystery  PG-13

# %%
tv = df[df['Type']=='TV Show']

# %%
tv
# Out:
#              Title     Type             Director  \
# 1  Stranger Things  TV Show  The Duffer Brothers
# 2     Breaking Bad  TV Show       Vince Gilligan
# 3      Money Heist  TV Show            Álex Pina
# 6             Dark  TV Show        Baran bo Odar
# 7        The Crown  TV Show         Peter Morgan
# 9           Narcos  TV Show       Chris Brancato
#
#                                 Cast         Country  Release Date   Duration  \
# 1  Millie Bobby Brown, Finn Wolfhard   United States          2016  3 Seasons
# 2         Bryan Cranston, Aaron Paul   United States          2008  5 Seasons
# 3       Úrsula Corberó, Álvaro Morte           Spain          2017  4 Seasons
# 6         Louis Hofmann, Lisa Vicari         Germany          2017  3 Seasons
# 7          Claire Foy, Olivia Colman  United Kingdom          2016  4 Seasons
# 9         Wagner Moura, Pedro Pascal   United States          2015  3 Seasons
#
#       Genre Rating
# 1    Sci-Fi  TV-14
# 2     Drama  TV-MA
# ...

# %%
df['Duration'] = df['Duration'].str.replace(' Seasons','',regex = False)

# %%
df
# Out:
#              Title     Type             Director  \
# 0     The Irishman    Movie      Martin Scorsese
# 1  Stranger Things  TV Show  The Duffer Brothers
# 2     Breaking Bad  TV Show       Vince Gilligan
# 3      Money Heist  TV Show            Álex Pina
# 4       Extraction    Movie         Sam Hargrave
# 5         Bird Box    Movie         Susanne Bier
# 6             Dark  TV Show        Baran bo Odar
# 7        The Crown  TV Show         Peter Morgan
# 8     Enola Holmes    Movie       Harry Bradbeer
# 9           Narcos  TV Show       Chris Brancato
#
#                                 Cast         Country  Release Date Duration  \
# 0          Robert De Niro, Al Pacino   United States          2019  209 min
# 1  Millie Bobby Brown, Finn Wolfhard   United States          2016        3
# 2         Bryan Cranston, Aaron Paul   United States          2008        5
# 3       Úrsula Corberó, Álvaro Morte           Spain          2017        4
# ...

# %%
df['Duration'] = df['Duration'].str.replace(' min','',regex = False)

# %%
df
# Out:
#              Title     Type             Director  \
# 0     The Irishman    Movie      Martin Scorsese
# 1  Stranger Things  TV Show  The Duffer Brothers
# 2     Breaking Bad  TV Show       Vince Gilligan
# 3      Money Heist  TV Show            Álex Pina
# 4       Extraction    Movie         Sam Hargrave
# 5         Bird Box    Movie         Susanne Bier
# 6             Dark  TV Show        Baran bo Odar
# 7        The Crown  TV Show         Peter Morgan
# 8     Enola Holmes    Movie       Harry Bradbeer
# 9           Narcos  TV Show       Chris Brancato
#
#                                 Cast         Country  Release Date Duration  \
# 0          Robert De Niro, Al Pacino   United States          2019      209
# 1  Millie Bobby Brown, Finn Wolfhard   United States          2016        3
# 2         Bryan Cranston, Aaron Paul   United States          2008        5
# 3       Úrsula Corberó, Álvaro Morte           Spain          2017        4
# ...

# %%
df['Duration']= df['Duration'].astype(int)

# %%
df
# Out:
#              Title     Type             Director  \
# 0     The Irishman    Movie      Martin Scorsese
# 1  Stranger Things  TV Show  The Duffer Brothers
# 2     Breaking Bad  TV Show       Vince Gilligan
# 3      Money Heist  TV Show            Álex Pina
# 4       Extraction    Movie         Sam Hargrave
# 5         Bird Box    Movie         Susanne Bier
# 6             Dark  TV Show        Baran bo Odar
# 7        The Crown  TV Show         Peter Morgan
# 8     Enola Holmes    Movie       Harry Bradbeer
# 9           Narcos  TV Show       Chris Brancato
#
#                                 Cast         Country  Release Date  Duration  \
# 0          Robert De Niro, Al Pacino   United States          2019       209
# 1  Millie Bobby Brown, Finn Wolfhard   United States          2016         3
# 2         Bryan Cranston, Aaron Paul   United States          2008         5
# 3       Úrsula Corberó, Álvaro Morte           Spain          2017         4
# ...

# %%
m = df[df['Type']== 'Movie']

# %%
m
# Out:
#           Title   Type         Director                              Cast  \
# 0  The Irishman  Movie  Martin Scorsese         Robert De Niro, Al Pacino
# 4    Extraction  Movie     Sam Hargrave                   Chris Hemsworth
# 5      Bird Box  Movie     Susanne Bier                    Sandra Bullock
# 8  Enola Holmes  Movie   Harry Bradbeer  Millie Bobby Brown, Henry Cavill
#
#           Country  Release Date  Duration     Genre Rating
# 0   United States          2019       209     Crime      R
# 4   United States          2020       117    Action      R
# 5   United States          2018       124  Thriller      R
# 8  United Kingdom          2020       123   Mystery  PG-13

# %%
avg_m = m['Duration'].mean()                  -- 5

# %%
avg_m
# Out:
# 143.25

# %%
tv_show = df[df['Type']== 'TV Show']

# %%
tv_show
# Out:
#              Title     Type             Director  \
# 1  Stranger Things  TV Show  The Duffer Brothers
# 2     Breaking Bad  TV Show       Vince Gilligan
# 3      Money Heist  TV Show            Álex Pina
# 6             Dark  TV Show        Baran bo Odar
# 7        The Crown  TV Show         Peter Morgan
# 9           Narcos  TV Show       Chris Brancato
#
#                                 Cast         Country  Release Date  Duration  \
# 1  Millie Bobby Brown, Finn Wolfhard   United States          2016         3
# 2         Bryan Cranston, Aaron Paul   United States          2008         5
# 3       Úrsula Corberó, Álvaro Morte           Spain          2017         4
# 6         Louis Hofmann, Lisa Vicari         Germany          2017         3
# 7          Claire Foy, Olivia Colman  United Kingdom          2016         4
# 9         Wagner Moura, Pedro Pascal   United States          2015         3
#
#       Genre Rating
# 1    Sci-Fi  TV-14
# 2     Drama  TV-MA
# ...

# %%
avg_tv = tv_show['Duration'].mean()

# %%
avg_tv
# Out:
# 3.6666666666666665

# %%
df
# Out:
#              Title     Type             Director  \
# 0     The Irishman    Movie      Martin Scorsese
# 1  Stranger Things  TV Show  The Duffer Brothers
# 2     Breaking Bad  TV Show       Vince Gilligan
# 3      Money Heist  TV Show            Álex Pina
# 4       Extraction    Movie         Sam Hargrave
# 5         Bird Box    Movie         Susanne Bier
# 6             Dark  TV Show        Baran bo Odar
# 7        The Crown  TV Show         Peter Morgan
# 8     Enola Holmes    Movie       Harry Bradbeer
# 9           Narcos  TV Show       Chris Brancato
#
#                                 Cast         Country  Release Date  Duration  \
# 0          Robert De Niro, Al Pacino   United States          2019       209
# 1  Millie Bobby Brown, Finn Wolfhard   United States          2016         3
# 2         Bryan Cranston, Aaron Paul   United States          2008         5
# 3       Úrsula Corberó, Álvaro Morte           Spain          2017         4
# ...

# %%
r = df['Rating']
